# %% [markdown]
# # Raster analysis - Advanced concepts

# %% [markdown]
# ## Access Landsat imagery

# %%
from arcgis.gis import GIS

# %%
gis = GIS()

# %%
landsat_item = gis.content.search('Multispectral Landsat', 'Imagery Layer', outside_org=True)[0]

# %%
landsat_item
# Out:
# <Item title:"Pansharpened Landsat" type:Imagery Layer owner:esri>

# %% [markdown]
# ## View Landsat imagery layer item description

# %%
from IPython.display import HTML
HTML(landsat_item.description)
# Out:
# <p style=''>Landsat 8 OLI, 15m multitemporal PanSharpened Natural Color images.&nbsp; Time-enabled for visualization and analytics, this imagery layer pulls directly from the&nbsp;<a href='https://aws.amazon.com/public-datasets/landsat/'>Landsat on AWS</a>&nbsp;collection and is updated daily with new imagery.</p><p style=''><span style='text-align: start;'>Geographic Coverage</span><br /></p><p style='text-align: justify;'></p><ul><li>World-wide imagery coverage.</li><li>Polar regions are available in polar-projected Imagery Layers:&nbsp;&nbsp;<a href='http://www.arcgis.com/home/item.html?id=6334dd0f09f04a3583a37233540d73c0' target='_blank'>Landsat Arctic Views</a>&nbsp;and&nbsp;<a href='http://www.arcgis.com/home/item.html?id=c391d600102e48a6bbd82ffe28941bf5' target='_blank'>Landsat Antarctic Views</a>.</li></ul><p></p><p><span style='line-height: 16.05px;'>Temporal Coverage</span></p><p></p><ul><li>This layer is updated daily with new imagery.<br /></li><li><span style='font-variant-numeric: normal; font-variant-east-asian: normal; font-stretch: normal; line-height: normal;'>&nbsp;</span><span style='text-indent: -0.25in;'>Landsat 8 imagery is collected for each point on Earth every 16 days.</span></li><li>Most images collected from January 2015 to present are included.<br /></li><li>Approximately 5 images for each path/row from 2013 and 2014 are also included.</li><li>The layer also includes imagery from the Global Land Survey* (circa 2010, 2005, 2000, 1990, 1975).<br /></li></ul><p></p><p><span style='line-height: 16.05px;'>Analysis Ready</span></p><p></p><p><span style='line-height: 16.05px;'></span></p><ul><li>This Imagery Layer&nbsp;is analysis ready with Top of Atmosphere (TOA) correction applied.</li><li>The&nbsp;<span style='text-indent: -0.25in;'>TOA&nbsp;</span><span style='text-indent: -0.25in;'>reflectance values (ranging 0 – 1 by default) are scaled using a range of 0 – 10,000.</span></li><li>The scale is equivalent to other TOA reflectance products, including those provided by the USGS.</li></ul><p><span style='line-height: 16.05px;'>Image Selection/Filtering</span></p><p></p><ul><li>The three most recent and cloud free images for any area are available by default.</li><li>The entire archive is accessible via custom filtering.</li><li>A number of fields are available for filtering, including Acquisition Date, Estimated Cloud Cover, and Product ID.</li><li>Landsat_product_id<span style='text-indent: -0.25in;'>&nbsp;distinguishes between Pre-Collection and Collection 1 data.&nbsp;&nbsp;<a href='https://ldcm.usgs.gov/landsat-collections'>More…</a></span></li><li><span style='text-indent: -0.25in;'>By setting the filter to Best is lesser than&nbsp;QQQQ one can control to see the best N scenes, where QQQQ=N*1million.</span></li></ul><p></p><p style='margin-left: 0.5in;'>NOTE:&nbsp; Turning off all filters, and loading the entire archive, may affect performance.</p><p>Visual Rendering<br /></p><p></p><ul><li>Default rendering is PanSharpened Natural Color images.</li><li><span style='text-indent: -0.25in;'>Raster Functions enable on-the-fly rendering of band combinations and calculated indices from the source imagery.</span></li><li>The DRA version of each layer enables visualization of the full dynamic range of the images.</li><li>Other pre-defined Raster Functions can be selected via the renderer drop-down or custom functions can be created.</li><li>This layer is part of a larger collection of&nbsp;<a href='https://www.arcgis.com/home/item.html?id=4ca13f0e4e29403fa68c46d188c4be73'>Landsat Imagery Layers</a>&nbsp;that you can use to perform a variety of mapping analysis tasks.</li></ul><p></p><p>Additional Usage Notes<br /></p><p></p><ul><li>Overviews exist with a spatial resolution of 300m and are updated weekly based on the best and latest imagery available at that time.</li><li>To work with individual source images at all scales, either use the ‘Lock Raster’ functionality or add a query filter to restrict the di ...

# %% [markdown]
# ## Access the layers available with the Landsat Imagery Layer item

# %%
landsat = landsat_item.layers[0]
landsat
# Out:
# <ImageryLayer url:"https://landsat2.arcgis.com/arcgis/rest/services/Landsat/PS/ImageServer">

# %% [markdown]
# ## Explore different wavelength bands

# %%
import pandas as pd

# %%
pd.DataFrame(landsat.key_properties()['BandProperties'])
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %% [markdown]
# ## Visualize the layer in the map widget

# %%
m = gis.map('Redlands, CA')
m
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-3aa963c0-7638-4985-bbd0-774a770b1187"><img src=""></img></div>

# %%
m.add_layer(landsat)

# %% [markdown]
# ## Apply built-in raster functions

# %%
for rasterFunc in landsat.properties.rasterFunctionInfos:
    print(rasterFunc.name)
# Out:
# Pansharpened Enhanced with DRA
# Pansharpened Natural Color
# None

# %%
from arcgis.raster.functions import apply

# %%
color_infrared = apply(landsat, 'Color Infrared with DRA')

# %%
m2 = gis.map('Redlands, CA')
m2.add_layer(color_infrared)
m2
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-4a11bfec-7a43-4ef3-8a52-0a98b9bc75ee"><img src=""></img></div>

# %% [markdown]
# ## Interactive raster processing in Jupyter Notebook

# %%
color_infrared
# Out:
# <ImageryLayer url:"https://landsat2.arcgis.com/arcgis/rest/services/Landsat/PS/ImageServer">

# %% [markdown]
# ### Setting an area of interest

# %%
from arcgis.geocoding import geocode
area = geocode('Redlands, CA', out_sr=landsat.properties.spatialReference)[0]

# %%
color_infrared.extent = area['extent']

# %%
color_infrared
# Out:
# <ImageryLayer url:"https://landsat2.arcgis.com/arcgis/rest/services/Landsat/PS/ImageServer">

# %%
landsat.extent = area['extent']
landsat
# Out:
# <ImageryLayer url:"https://landsat2.arcgis.com/arcgis/rest/services/Landsat/PS/ImageServer">

# %% [markdown]
# ## Exporting Images from Imagery Layer

# %%
from IPython.display import Image

# %%
image = landsat.export_image(bbox=area['extent'], size=[1200,450], f='image')

# %%
Image(image)

# %%
savedimage = landsat.export_image(bbox=area['extent'],
                                  size=[1200,450],
                                  f='image',
                                  save_folder='.',
                                  save_file='image.jpg')

# %%
savedimage
# Out:
# './image.jpg'

# %%
from IPython.display import Image

# %%
Image(filename=savedimage, width=1200, height=450)

# %% [markdown]
# ## Exporting images from an imagery layer to which a raster function has been applied

# %%
color_infrared = apply(landsat, 'Color Infrared with DRA')

# %%
image = color_infrared.export_image(bbox=area['extent'], size=[1200, 450], f='image')

# %%
Image(image)

# %% [markdown]
# ## Vegetation Index

# %%
ndvi_colorized = apply(landsat, 'NDVI Colorized')
ndvi_colorized
# Out:
# <ImageryLayer url:"https://landsat2.arcgis.com/arcgis/rest/services/Landsat/PS/ImageServer">

# %% [markdown]
# ## Custom Bands

# %%
from arcgis.raster.functions import stretch, extract_band

# %%
naturalcolor = stretch(extract_band(landsat, [3, 2, 1]),
                       stretch_type='percentclip',
                       min_percent=0.1,
                       max_percent=0.1,
                       gamma=[1, 1, 1],
                       dra=True)

# %%
naturalcolor
# Out:
# <ImageryLayer url:"https://landsat2.arcgis.com/arcgis/rest/services/Landsat/PS/ImageServer">

# %% [markdown]
# ## Image Attributes

# %%
import arcgis
g = arcgis.geometry.Geometry(area['extent'])

# %%
samples = landsat.get_samples(g,
                              sample_count=50,
                              out_fields='AcquisitionDate,OBJECTID,GroupName,Category,SunAzimuth,SunElevation,CloudCover')

# %%
samples[0]
# Out:
# {'location': {'x': -13051569.97725714,
#   'y': 4044790.7833781266,
#   'spatialReference': {'wkid': 102100, 'latestWkid': 3857}},
#  'locationId': 0,
#  'value': '1639 1473 1427',
#  'rasterId': 1249137,
#  'resolution': 15,
#  'attributes': {'AcquisitionDate': 1560018116279,
#   'OBJECTID': 1249137,
#   'GroupName': 'LC80400362019159LGN00_MTL',
#   'Category': 1,
#   'SunAzimuth': 116.9961,
#   'SunElevation': 68.19199,
#   'CloudCover': 0.0006},
#  'values': [1639.0, 1473.0, 1427.0]}

# %%
import datetime
value = samples[0]['attributes']['AcquisitionDate']
datetime.datetime.fromtimestamp(value / 1000).strftime("Acquisition Date: %d %b, %Y")
# Out:
# 'Acquisition Date: 08 Jun, 2019'

# %%
pd.DataFrame(samples[0]['attributes'], index=[0])
# Out:
#    AcquisitionDate  OBJECTID                  GroupName  Category  SunAzimuth  \
# 0    1560018116279   1249137  LC80400362019159LGN00_MTL         1    116.9961
#
#    SunElevation  CloudCover
# 0      68.19199      0.0006

# %% [markdown]
# ## Spectral profile from the sampled values at a location

# %%
m3 = gis.map('Redlands, CA')
m3
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-12a9ccbe-8f98-4b38-b715-5736086790c4"><img src=""></img></div>

# %%
m3.add_layer(landsat)

# %%
from bokeh.models import Range1d
from bokeh.plotting import figure, show, output_notebook
from IPython.display import clear_output
output_notebook()

def get_samples(mw, g):
    clear_output()
    m.draw(g)
    samples = landsat.get_samples(g, pixel_size=30)
    values = samples[0]['value']
    vals = [float(int(s) / 100000) for s in values.split(' ')]
    
    x = ['1', '2', '3', '4', '5', '6', '7', '8']
    y = vals
    p = figure(title="Spectral Profile", x_axis_label='Spectral Bands', y_axis_label='Data Values', width=600, height=300)
    p.line(x, y, legend="Selected Point", line_color="red", line_width=2)
    p.circle(x, y, line_color="red", fill_color="white", size=8)
    p.y_range=Range1d(0, 1.0)

    show(p)
    
print('Click anywhere on the map to plot the spectral profile for that location.')
m.on_click(get_samples)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# Click anywhere on the map to plot the spectral profile for that location.

# %% [markdown]
# ## Clipping to an area of interest

# %%
from arcgis.geometry import Geometry, buffer

# %%
poly = buffer(geometries=[Geometry(area['location'])],
              in_sr=102100,
              distances=6000,
              unit='esriMeters')[0]

# %%
from arcgis.raster.functions import clip

# %%
redclip = clip(landsat, poly)

# %%
m4 = gis.map('Redlands, CA')

# %%
m4
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-809861ba-f6de-404e-8f03-929e852e389d"><img src=""></img></div>

# %%
m4.add_layer(redclip)

# %% [markdown]
# ## Select images by where clause, geometry and time range

# %%
selected = landsat.filter_by(where="(Category = 1) AND (CloudCover <=0.10) AND (WRS_Row = 36)",
                             geometry=arcgis.geometry.filters.intersects(area['extent']))

# %%
fs = selected.query(out_fields="AcquisitionDate, GroupName, Best, CloudCover, WRS_Row, Month, Name",
                    return_geometry=True,
                    return_distinct_values=False,
                    order_by_fields="AcquisitionDate")

# %%
df = fs.sdf
df.head()
# Out:
#                 AcquisitionDate      Best  CloudCover  \
# 0 2000-04-24 00:00:00.000000000  88960036      0.0000
# 1 2005-05-24 00:00:00.000000000  79960036      0.0000
# 2 2014-04-07 18:22:17.313999891  84960036      0.0045
# 3 2014-09-30 18:22:18.497999907  80960036      0.0043
# 4 2014-10-16 18:22:23.338000059  82960036      0.0194
#
#                    GroupName  Month                     Name  OBJECTID  \
# 0        p040r036_7x20000424      4   p040r036_7x20000424_PS    664535
# 1       L7040036_03620050524      5  L7040036_03620050524_PS    673670
# 2  LC80400362014097LGN00_MTL      4    LC80400362014097LGN00     84426
# 3  LC80400362014273LGN00_MTL      9    LC80400362014273LGN00     84427
# 4  LC80400362014289LGN00_MTL     10    LC80400362014289LGN00     84428
#
#                                                SHAPE    Shape_Area  \
# 0  {"rings": [[[-12872961.873599999, 4197538.7916...  4.600983e+10
# 1  {"rings": [[[-12867140.4332, 4198647.7443], [-...  4.766887e+10
# 2  {"rings": [[[-12868346.0088, 4199764.671300001...  5.109227e+10
# 3  {"rings": [[[-12863947.662999999, 4199535.1133...  5.110416e+10
# 4  {"rings": [[[-12865784.5616, 4199562.156599998...  5.110299e+10
#
#     Shape_Length  WRS_Row
# 0  858608.456217       36
# 1  874086.578684       36
# 2  904494.753605       36
# 3  904595.143358       36
# 4  904595.590773       36

# %%
df.shape
# Out:
# (72, 11)

# %%
df['Time'] = pd.to_datetime(df['AcquisitionDate'], unit='ms')
df['Time'].head(10)
# Out:
# 0   2000-04-24 00:00:00.000000000
# 1   2005-05-24 00:00:00.000000000
# 2   2014-04-07 18:22:17.313999891
# 3   2014-09-30 18:22:18.497999907
# 4   2014-10-16 18:22:23.338000059
# 5   2014-11-17 18:22:20.786999941
# 6   2014-12-19 18:22:16.836999893
# 7   2015-02-05 18:22:04.519000052
# 8   2015-03-09 18:21:48.729000092
# 9   2015-03-25 18:21:40.197999954
# Name: Time, dtype: datetime64[ns]

# %% [markdown]
# ## Resolving overlapping pixels in selected rasters

# %%
m5 = gis.map('Redlands, CA', 7)
display(m5)
m5.add_layer(selected.last())
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=7.0)
# <div class="map-static-img-preview-9589c6d4-dfdb-47d8-a313-1d0670635f56"><img src=""></img></div>

# %%
m6 = gis.map('Redlands, CA', 7)
display(m6)
m6.add_layer(selected.first())
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=7.0)
# <div class="map-static-img-preview-084fd48b-8f88-41d7-8439-b0107382d556"><img src=""></img></div>

# %% [markdown]
# ## Change Detection

# %%
old = landsat.filter_by('OBJECTID=1139')

# %%
new = landsat.filter_by('OBJECTID=463490')

# %% [markdown]
# ## Difference Image

# %%
from arcgis.raster.functions import *

# %%
diff = stretch(composite_band([ndvi(old, '5 4'), ndvi(new, '5 4'), ndvi(old, '5 4')]),
               stretch_type='stddev',
               num_stddev=3,
               min=0,
               max=255,
               dra=True,
               astype='u8')
diff
# Out:
# <ImageryLayer url:"https://landsat2.arcgis.com/arcgis/rest/services/Landsat/PS/ImageServer">

# %% [markdown]
# ## Applying a threshold mask

# %%
ndvi_diff = ndvi(new, '5 4') - ndvi(old, '5 4')

# %%
ndvi_diff
# Out:
# <ImageryLayer url:"https://landsat2.arcgis.com/arcgis/rest/services/Landsat/PS/ImageServer">

# %%
threshold_val = 0.1

# %%
masked = colormap(remap(ndvi_diff,
                        input_ranges=[threshold_val, 1],
                        output_values=[1],
                        no_data_ranges=[-1, threshold_val], astype='u8'),
                  colormap=[[1, 124, 252, 0]], astype='u8')

Image(masked.export_image(bbox=area['extent'], size=[1200,450], f='image'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1253         try:
# -> 1254             b64_data = b2a_base64(self.data).decode('ascii')
#    1255         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1242         if self.embed:
#    1243             mimetype = self._mimetype
# -> 1244             data, metadata = self._data_and_metadata(always_both=True)
#    1245             if metadata:
#    1246                 metadata = {mimetype: metadata}
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1255         except TypeError:
#    1256             raise FileNotFoundError(
# -> 1257                 "No such file or directory: '%s'" % (self.data))
#    1258         md = {}
#    1259         if self.metadata:
#
# FileNotFoundError: No such file or directory: '{"error":{"code":400,"message":"Invalid or missing input parameters.","details":[]}}'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1253         try:
# -> 1254             b64_data = b2a_base64(self.data).decode('ascii')
#    1255         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/display.py in _repr_png_(self)
#    1272     def _repr_png_(self):
#    1273         if self.embed and self.format == self._FMT_PNG:
# -> 1274             return self._data_and_metadata()
#    1275
#    1276     def _repr_jpeg_(self):
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1255         except TypeError:
#    1256             raise FileNotFoundError(
# -> 1257                 "No such file or directory: '%s'" % (self.data))
#    1258         md = {}
#    1259         if self.metadata:
#
# FileNotFoundError: No such file or directory: '{"error":{"code":400,"message":"Invalid or missing input parameters.","details":[]}}'

# %%
m7 = gis.map('Redlands, CA')
m7
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-65da69c6-806c-4883-8be8-b476fe827a13"><img src=""></img></div>

# %%
m7.add_layer(diff)

# %%
m7.add_layer(masked)

# %% [markdown]
# ## Persisting your analysis for visualizaion or analysis

# %%
layer = masked.save('Test_viz_layer3', for_viz=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-67-9fec2a75c7fc> in <module>
# ----> 1 layer = masked.save('Test_viz_layer3', for_viz=True)
#
# /anaconda3/lib/python3.6/site-packages/arcgis/raster/_layer.py in save(self, output_name, for_viz, gis, **kwargs)
#    2486                 return g.content.add(item_properties)
#    2487             else:
# -> 2488                 raise RuntimeError('You need to be signed in to a GIS to create Items')
#    2489         else:
#    2490             from .analytics import is_supported, generate_raster, _save_ra
#
# RuntimeError: You need to be signed in to a GIS to create Items

# %%
layer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-b34461a6889d> in <module>
# ----> 1 layer
#
# NameError: name 'layer' is not defined
